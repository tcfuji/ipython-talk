# %%
from IPython.display import Image
import numpy as np
from pylab import rcParams
# %matplotlib inline

rcParams['figure.figsize'] = 6, 6

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# # Learning Python with IPython/Jupyter

# %% [markdown]
# ## What is it?

# %% [markdown]
# > The Jupyter Notebook is a web application that allows you to create and share documents that contain live code, equations, visualizations and explanatory text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, machine learning and much more.

# %% [markdown]
# ## History of IPython/Jupyter

# %% [markdown]
# #### Quote by Prof. Fernando Perez (Jupyter BDFL)

# %% [markdown]
# > I created the IPython project while a graduate student in 2001 and continue to lead the project, now as a collaborative effort with a talented team that does all the hard work.

# %% [markdown]
# #### Is it IPython or Jupyter?!

# %% [markdown]
# #### Answer: Both!

# %% [markdown]
# Explanation: The IPython kernel could be used for programming languages other than Python. The IPython kernel is the Python execution backend for Jupyter

# %%
Image('pics/kernels.jpg', width=600, height=600)

# %% [markdown]
# ## What can I do with it?

# %% [markdown]
# #### How are you currently learning Python now?

# %% [markdown]
# - Python Interpreter
# - Running Python files on command line
# - IDE
# - IDLE

# %% [markdown]
# IPython can:
#
# - make learning Python a breeze with the convenience of a text editor and a Python interpreter in one application.
# - document your work.
# - help you provide lectures for other learners!

# %% [markdown]
# ## Let's try it out!

# %%
print("Hello pyladies!")
# Out:
# Hello pyladies!

# %%
x = 3 ** 3
print(x)
# Out:
# 27

# %%
y = x + 1
print(y)
# Out:
# 28

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)
# Out:
# (-100, 100)

# %%
# Remember to install rpy2
# %load_ext rpy2.ipython

# %%
# %%R
# library(ggplot2)
# dat <- data.frame(cond = rep(c("A", "B"), each=10),
#                   xvar = 1:20 + rnorm(20,sd=3),
#                   yvar = 1:20 + rnorm(20,sd=3))
#
# ggplot(dat, aes(x=xvar, y=yvar)) +
#     geom_point(shape=1) +    # Use hollow circles
#     geom_smooth(method=lm)   # Add linear regression line

# %% [markdown]
# - [Running Code](https://nbviewer.jupyter.org/github/jupyter/notebook/blob/master/docs/source/examples/Notebook/Running%20Code.ipynb)
# - [XKCD plots in Matplotlib](http://nbviewer.jupyter.org/url/jakevdp.github.com/downloads/notebooks/XKCD_plots.ipynb)
# - [Probabilistic Programming and Bayesian Methods for Hackers](http://nbviewer.jupyter.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter1_Introduction/Chapter1.ipynb)
# - [Introduction to Scikit-Learn: Machine Learning with Python](http://nbviewer.jupyter.org/github/jakevdp/sklearn_tutorial/blob/master/notebooks/02.1-Machine-Learning-Intro.ipynb)

# %% [markdown]
# ## Making Computational Science Interactive

# %% [markdown]
# - [The Traveling Salesperson Problem](http://nbviewer.jupyter.org/url/norvig.com/ipython/TSP.ipynb)
# - [A Concrete Introduction to Probability (using Python)](http://nbviewer.jupyter.org/url/norvig.com/ipython/Probability.ipynb)
# - [Predicting Coronal Mass Ejections Using Machine Learning Methods](http://nbviewer.jupyter.org/github/mbobra/machine-learning-with-solar-data/blob/master/cme_svm.ipynb)
# - [Discovery of Gravitational Waves by the LIGO collaboration](https://losc.ligo.org/tutorials)

# %% [markdown]
# ## Jupyter Ecosystem

# %% [markdown]
# ### 1. [Reveal.js](http://lab.hakim.se/reveal-js) slideshows!

# %% [markdown]
# ### 2. [Jupyterhub](https://github.com/jupyter/jupyterlab) for [large classes](https://developer.rackspace.com/blog/deploying-jupyterhub-for-education/)

# %% [markdown]
# ### 3. [binder](http://mybinder.org/)

# %% [markdown]
# #### ...and much more!

# %% [markdown]
# ## Homework 1:

# %% [markdown]
# ### Run
# `$ pip install jupyter`
#
# `$ pip install notebook`

# %% [markdown]
# ## Homework 2

# %% [markdown]
# Make some jupyter-notebooks for https://github.com/forastera/Data-Science-Light
